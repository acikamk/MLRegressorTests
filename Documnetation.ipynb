# %%
# just load every module I used
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy import sparse 
from sklearn.decomposition import PCA
from sklearn import metrics 
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.ensemble import RandomForestRegressor 
from xgboost import XGBRegressor
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import GridSearchCV 
from pprint import pprint 
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from nltk import PorterStemmer
from nltk.stem.snowball import GermanStemmer
from sklearn import preprocessing
import spacy
from pandas.plotting import scatter_matrix

# nlp=spacy.load('de')

# %%
# read in data and preform simple of empty data and uniquness of the given features
data = pd.read_csv('~/Downloads/ml-price-prediction-dataset.csv', sep=';', low_memory=False, encoding='latin')
data
# Out:
#        restaurant_id      restaurant_name  testing  \
# 0                453  fit kitchen eat fit        0
# 1                453  fit kitchen eat fit        0
# 2                453  fit kitchen eat fit        0
# 3                453  fit kitchen eat fit        0
# 4                453  fit kitchen eat fit        0
# 5                453  fit kitchen eat fit        0
# 6                453  fit kitchen eat fit        0
# 7                453  fit kitchen eat fit        0
# 8                453  fit kitchen eat fit        0
# 9                453  fit kitchen eat fit        0
# 10               453  fit kitchen eat fit        0
# 11               453  fit kitchen eat fit        0
# 12               453  fit kitchen eat fit        0
# 13               453  fit kitchen eat fit        0
# 14               453  fit kitchen eat fit        0
# 15               358           a tavola !        0
# 16               358           a tavola !        0
# 17               358           a tavola !        0
# 18               358           a tavola !        0
# 19               358           a tavola !        0
# 20               358           a tavola !        0
# 21               358           a tavola !        0
# 22               358           a tavola !        0
# 23               358           a tavola !        0
# 24               358           a tavola !        0
# 25               358           a tavola !        0
# 26               358           a tavola !        0
# 27               358           a tavola !        0
# 28               358           a tavola !        0
# 29               358           a tavola !        0
# ...              ...                  ...      ...
# 65469           8649               kavala        0
# 65470           8649               kavala        0
# 65471           8649               kavala        0
# 65472           8649               kavala        0
# 65473           8649               kavala        0
# 65474           8649               kavala        0
# 65475           8649               kavala        0
# 65476           8649               kavala        0
# 65477           8649               kavala        0
# 65478           8649               kavala        0
# 65479           8649               kavala        0
# 65480           8649               kavala        0
# 65481           8649               kavala        0
# 65482           8649               kavala        0
# 65483           8649               kavala        0
# 65484           8649               kavala        0
# 65485           8649               kavala        0
# 65486           8649               kavala        0
# 65487           8649               kavala        0
# 65488           8649               kavala        0
# 65489           8649               kavala        0
# 65490           8649               kavala        0
# 65491           8649               kavala        0
# 65492           8649               kavala        0
# 65493           8649               kavala        0
# 65494           8649               kavala        0
# 65495           8649               kavala        0
# 65496           8649               kavala        0
# 65497           8649               kavala        0
# 65498           8649               kavala        0
#
#                   restaurant_description  product_id  variation_id  \
# 0                     gesundes fast food       35039         35037
# 1                     gesundes fast food       35040         35038
# 2                     gesundes fast food       35043         35041
# 3                     gesundes fast food       35045         35043
# 4                     gesundes fast food       35046         35044
# 5                     gesundes fast food       35051         35049
# 6                     gesundes fast food       35052         35050
# 7                     gesundes fast food       35053         35051
# 8                     gesundes fast food       35059         35057
# 9                     gesundes fast food       35060         35058
# 10                    gesundes fast food       35063         35061
# 11                    gesundes fast food       35069         35067
# 12                    gesundes fast food       35070         35068
# 13                    gesundes fast food       35082         35080
# 14                    gesundes fast food       35083         35081
# 15                 feinstes bella italia       35102         35100
# 16                 feinstes bella italia       35103         35101
# 17                 feinstes bella italia       35105         35103
# 18                 feinstes bella italia       35106         35104
# 19                 feinstes bella italia       35107         35105
# 20                 feinstes bella italia       35108         35106
# 21                 feinstes bella italia       35109         35107
# 22                 feinstes bella italia       35110         35108
# 23                 feinstes bella italia       35111         35109
# 24                 feinstes bella italia       35112         35110
# 25                 feinstes bella italia       35113         35111
# 26                 feinstes bella italia       35114         35112
# 27                 feinstes bella italia       35116         35114
# 28                 feinstes bella italia       35122         35120
# 29                 feinstes bella italia       35123         35121
# ...                                  ...         ...           ...
# 65469  goettliche gerichte griechenlands      219983        220669
# 65470  goettliche gerichte griechenlands      219984        220670
# 65471  goettliche gerichte griechenlands      219985        220671
# 65472  goettliche gerichte griechenlands      219986        220672
# 65473  goettliche gerichte griechenlands      219987        220673
# 65474  goettliche gerichte griechenlands      219988        220674
# 65475  goettliche gerichte griechenlands      219989        220675
# 65476  goettliche gerichte griechenlands      219990        220676
# 65477  goettliche gerichte griechenlands      219991        220677
# 65478  goettliche gerichte griechenlands      219992        220678
# 65479  goettliche gerichte griechenlands      219993        220679
# 65480  goettliche gerichte griechenlands      219994        220680
# 65481  goettliche gerichte griechenlands      219996        220682
# 65482  goettliche gerichte griechenlands      219997        220683
# 65483  goettliche gerichte griechenlands      220001        220687
# 65484  goettliche gerichte griechenlands      220002        220688
# 65485  goettliche gerichte griechenlands      220003        220689
# 65486  goettliche gerichte griechenlands      220004        220690
# 65487  goettliche gerichte griechenlands      220005        220691
# 65488  goettliche gerichte griechenlands      220006        220692
# 65489  goettliche gerichte griechenlands      220007        220693
# 65490  goettliche gerichte griechenlands      220015        220701
# 65491  goettliche gerichte griechenlands      220016        220702
# 65492  goettliche gerichte griechenlands      220018        220704
# 65493  goettliche gerichte griechenlands      220019        220705
# 65494  goettliche gerichte griechenlands      220020        220706
# 65495  goettliche gerichte griechenlands      220022        220708
# 65496  goettliche gerichte griechenlands      220023        220709
# 65497  goettliche gerichte griechenlands      220024        220710
# 65498  goettliche gerichte griechenlands      220025        220711
#
#                   menu_category                                 product_name  \
# 0                     fit pizza                             pizza margherita
# 1                     fit pizza                  pizza salami, putenschinken
# 2                     fit pizza                        pizza veggie + rucola
# 3                     fit pizza                        pizza sucuk jalapenos
# 4                     fit pizza                         pizza haehnchenbrust
# 5                    fit burger                              classic burger
# 6                    fit burger                                cheese burger
# 7                    fit burger                          chili cheese burger
# 8                  fit beilagen                                   fit pommes
# 9                  fit beilagen                                 fit coleslaw
# 10                    fit salat                         haehnchenbrust salat
# 11                    getraenke                  afri kola zuckerfrei, 0,33l
# 12                    getraenke                             afri kola, 0,33l
# 13                    getraenke  elisabethen quelle ohne kohlensaeure, 0,25l
# 14                    getraenke   elisabethen quelle mit kohlensaeure, 0,25l
# 15                    antipasti                           antipasti italiani
# 16                     insalate                               insalata mista
# 17                     insalate                             insalata caprese
# 18                     insalate                            insalata di pollo
# 19                     insalate                          insalata della casa
# 20                     insalate                            insalata di capra
# 21                        pasta                        spaghetti al pomodoro
# 22                        pasta                spaghetti aglio e peperoncino
# 23                        pasta                              penne arrabiata
# 24                        pasta                     spaghetti alla carbonara
# 25                        pasta                     spaghetti alla bolognese
# 26                        pasta                                penne verdure
# 27                        pasta                              penne salsiccia
# 28                        pizza                             pizza margherita
# 29                        pizza                                 pizza salami
# ...                         ...                                          ...
# 65469  spezialitaeten vom grill                         schweinefilet kavala
# 65470  spezialitaeten vom grill                schweinefilet in metaxa sauce
# 65471  spezialitaeten vom grill                               peramos teller
# 65472  spezialitaeten vom grill                              phillipi teller
# 65473  spezialitaeten vom grill                                  joti teller
# 65474  spezialitaeten vom grill                              keramoti teller
# 65475  spezialitaeten vom grill                             iraklitsa teller
# 65476  spezialitaeten vom grill                           rumpsteak vom rind
# 65477  spezialitaeten vom grill                                schweinefilet
# 65478  spezialitaeten vom grill                               spiesse teller
# 65479  spezialitaeten vom grill                                 filet spiess
# 65480                   platten                    platte fuer zwei personen
# 65481           pfannengerichte                                 gyros pfanne
# 65482           pfannengerichte                                 puten pfanne
# 65483              lammgerichte                          lammfilets gegrillt
# 65484              lammgerichte                                     arnissia
# 65485              lammgerichte                               lammkotelettes
# 65486              lammgerichte                                  lamm teller
# 65487              lammgerichte                 lammsteak mit kraeuterbutter
# 65488              lammgerichte                   lammsteak mit metaxa sauce
# 65489              lammgerichte               lamm platte fuer zwei personen
# 65490             fischgerichte                            garnelen gegrillt
# 65491             fischgerichte                      rotbarschfilet gebraten
# 65492             fischgerichte                     baby calamares frittiert
# 65493             fischgerichte                              dorade gegrillt
# 65494             fischgerichte                      baby calamares gegrillt
# 65495     erfrischungsgetraenke                              coca cola, 1,0l
# 65496     erfrischungsgetraenke                                  fanta, 1,0l
# 65497     erfrischungsgetraenke                                 sprite, 1,0l
# 65498     erfrischungsgetraenke                       coca cola light, 0,33l
#
#                                      product_description  price  \
# 0                       tomatensauce und fettarmer kaese    6.0
# 1      fettarme salami, putenschinken und fettarmer k...    8.4
# 2            pilze, zwiebeln, rucola und fettarmer kaese    8.4
# 3      fettarme knoblauchwurst, jalapenos und fettarm...    8.4
# 4      magere haehnchenbruststreifen, pilze, zwiebeln...    8.9
# 5      mageres rindfleisch, eisbergsalat, tomaten, zw...    5.9
# 6      mageres rindfleisch, low fat kaese, eisbergsal...    6.4
# 7      mageres rindfleisch, salat, jalapenos und fit ...    7.4
# 8                        mit heissluft frittierte pommes    2.9
# 9                                   fettarmer krautsalat    2.9
# 10     gemischter salat, haehnchenbruststreifen, dazu...    7.9
# 11     erfrischungsgetraenk, inkl. 0,08 pfand, 8,55 l...    2.9
# 12     erfrischungsgetraenk, inkl. 0,08 pfand, 8,55 l...    2.9
# 13                  wasser, inkl. 0,15 pfand, 8,20 liter    2.2
# 14                  wasser, inkl. 0,15 pfand, 8,20 liter    2.2
# 15     bresaola schinken, salami, parmesan, champigno...   10.5
# 16     verschiedene salate, tomaten, karotten, gurken...    6.0
# 17                        tomaten, burrata und basilikum    8.5
# 18     verschiedene salate, tomaten und gebratene hae...   10.5
# 19       blattsalate, thunfisch, oliven, zwiebeln und ei   10.0
# 20     rucolasalat mir warmen ziegenkaese, kirschtoma...    9.5
# 21                             tomatensugo und basilikum    6.5
# 22            knoblauch, chili, olivenoel und petersilie    7.5
# 23         mit tomatensauce, basilikum, knoblauch scharf    8.0
# 24                               ei und speck ohne sahne    9.5
# 25                          mit rinderhackfleisch ragout    9.5
# 26                     tomatensauce und frisches gemuese    9.0
# 27     pikante salsiccia, tomaten und weisswein tomat...   11.0
# 28                              mozzarella und basilikum    6.0
# 29                                 mozzarella und salami    7.0
# ...                                                  ...    ...
# 65469  vier schweinefilets mit kraeuterbutter, dazu p...   13.9
# 65470  in metaxa sauce mit gouda ueberbacken, dazu po...   14.5
# 65471  souvlaki, lammkotelett, ÄevapÄiÄi, schweine...   14.9
# 65472  gyros, zwei ÄevapÄiÄi, schweinefilet und tz...   13.5
# 65473  gyros, schweinesteak, schweinefilet, souvlaki,...   14.9
# 65474  gyros, souvlaki, lammkotelett und tzatziki, da...   14.5
# 65475  souvlaki, zwei ÄevapÄiÄi, schweinefilet, la...   14.9
# 65476  mit kraeuterbutter, dazu pommes frites und sal...   16.9
# 65477                  mit pommes frites, reis und salat   14.5
# 65478  ein schweinefleischspiess und ein lammfleischs...   12.9
# 65479  ein grosser schweinefiletspiess mit zwiebeln u...   14.2
# 65480  als vorspeise: tzatziki, tarama, krautsalat, t...   31.5
# 65481  in metaxa sauce, dazu pommes frites und salat,...   11.9
# 65482  in metaxa sauce, dazu pommes frites und salat,...   11.9
# 65483  mit kraeuterbutter, dazu pommes frites und sal...   15.9
# 65484  zwei lammspiesse, dazu pommes frites und salat...   13.9
# 65485  4 stueck, dazu pommes frites und salat, auf wu...   14.9
# 65486  zwei lammkoteletts, ein lammspiess und ein kle...   17.5
# 65487  mit kraeuterbutter, dazu pommes frites und sal...   14.9
# 65488  mit metaxa sauce, dazu pommes frites und salat...   15.9
# 65489  als vorspeise: tzatziki, tarama, krautsalat, t...   35.9
# 65490  dazu pommes frites und salat, auf wunsch auch ...   16.9
# 65491  dazu pommes frites und salat, auf wunsch auch ...   11.9
# 65492  dazu pommes frites und salat, auf wunsch auch ...   13.5
# 65493  dazu pommes frites und salat, auf wunsch auch ...   17.5
# 65494  dazu pommes frites und salat, auf wunsch auch ...   13.5
# 65495  erfrischungsgetraenk, inkl. 0,15 pfand, 2,35 l...    2.5
# 65496  erfrischungsgetraenk, inkl. 0,15 pfand, 2,35 l...    2.5
# 65497  erfrischungsgetraenk, inkl. 0,15 pfand, 2,35 l...    2.5
# 65498  erfrischungsgetraenk, dose, inkl. 0,25 pfand, ...    2.2
#
#                              ...                         longitude  chain_id  \
# 0                            ...                          8.684631       NaN
# 1                            ...                          8.684631       NaN
# 2                            ...                          8.684631       NaN
# 3                            ...                          8.684631       NaN
# 4                            ...                          8.684631       NaN
# 5                            ...                          8.684631       NaN
# 6                            ...                          8.684631       NaN
# 7                            ...                          8.684631       NaN
# 8                            ...                          8.684631       NaN
# 9                            ...                          8.684631       NaN
# 10                           ...                          8.684631       NaN
# 11                           ...                          8.684631       NaN
# 12                           ...                          8.684631       NaN
# 13                           ...                          8.684631       NaN
# 14                           ...                          8.684631       NaN
# 15                           ...                          8.681190       NaN
# 16                           ...                          8.681190       NaN
# 17                           ...                          8.681190       NaN
# 18                           ...                          8.681190       NaN
# 19                           ...                          8.681190       NaN
# 20                           ...                          8.681190       NaN
# 21                           ...                          8.681190       NaN
# 22                           ...                          8.681190       NaN
# 23                           ...                          8.681190       NaN
# 24                           ...                          8.681190       NaN
# 25                           ...                          8.681190       NaN
# 26                           ...                          8.681190       NaN
# 27                           ...                          8.681190       NaN
# 28                           ...                          8.681190       NaN
# 29                           ...                          8.681190       NaN
# ...                          ...                               ...       ...
# 65469                        ...                          6.778935       NaN
# 65470                        ...                          6.778935       NaN
# 65471                        ...                          6.778935       NaN
# 65472                        ...                          6.778935       NaN
# 65473                        ...                          6.778935       NaN
# 65474                        ...                          6.778935       NaN
# 65475                        ...                          6.778935       NaN
# 65476                        ...                          6.778935       NaN
# 65477                        ...                          6.778935       NaN
# 65478                        ...                          6.778935       NaN
# 65479                        ...                          6.778935       NaN
# 65480                        ...                          6.778935       NaN
# 65481                        ...                          6.778935       NaN
# 65482                        ...                          6.778935       NaN
# 65483                        ...                          6.778935       NaN
# 65484                        ...                          6.778935       NaN
# 65485                        ...                          6.778935       NaN
# 65486                        ...                          6.778935       NaN
# 65487                        ...                          6.778935       NaN
# 65488                        ...                          6.778935       NaN
# 65489                        ...                          6.778935       NaN
# 65490                        ...                          6.778935       NaN
# 65491                        ...                          6.778935       NaN
# 65492                        ...                          6.778935       NaN
# 65493                        ...                          6.778935       NaN
# 65494                        ...                          6.778935       NaN
# 65495                        ...                          6.778935       NaN
# 65496                        ...                          6.778935       NaN
# 65497                        ...                          6.778935       NaN
# 65498                        ...                          6.778935       NaN
#
#        restaurant_active  city_id  \
# 0                      1        9
# 1                      1        9
# 2                      1        9
# 3                      1        9
# 4                      1        9
# 5                      1        9
# 6                      1        9
# 7                      1        9
# 8                      1        9
# 9                      1        9
# 10                     1        9
# 11                     1        9
# 12                     1        9
# 13                     1        9
# 14                     1        9
# 15                     1        9
# 16                     1        9
# 17                     1        9
# 18                     1        9
# 19                     1        9
# 20                     1        9
# 21                     1        9
# 22                     1        9
# 23                     1        9
# 24                     1        9
# 25                     1        9
# 26                     1        9
# 27                     1        9
# 28                     1        9
# 29                     1        9
# ...                  ...      ...
# 65469                  1       12
# 65470                  1       12
# 65471                  1       12
# 65472                  1       12
# 65473                  1       12
# 65474                  1       12
# 65475                  1       12
# 65476                  1       12
# 65477                  1       12
# 65478                  1       12
# 65479                  1       12
# 65480                  1       12
# 65481                  1       12
# 65482                  1       12
# 65483                  1       12
# 65484                  1       12
# 65485                  1       12
# 65486                  1       12
# 65487                  1       12
# 65488                  1       12
# 65489                  1       12
# 65490                  1       12
# 65491                  1       12
# 65492                  1       12
# 65493                  1       12
# 65494                  1       12
# 65495                  1       12
# 65496                  1       12
# 65497                  1       12
# 65498                  1       12
#
#                                  dietary_characteristics  \
# 0                                  ['lakto vegetarisch']
# 1                                  ['lakto vegetarisch']
# 2      ['lakto vegetarisch', 'ohne rindfleisch', 'ohn...
# 3                                                    NaN
# 4                                              ['halal']
# 5                               ['ohne schweinefleisch']
# 6                               ['ohne schweinefleisch']
# 7                               ['ohne schweinefleisch']
# 8                                              ['vegan']
# 9                                                    NaN
# 10          ['ohne rindfleisch', 'ohne schweinefleisch']
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                        ['biologisch']
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21          ['ohne rindfleisch', 'ohne schweinefleisch']
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                              ['ohne schweinefleisch']
# 26                                                   NaN
# 27                              ['ohne schweinefleisch']
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 65469                      ['glutenfrei', 'laktosefrei']
# 65470                                     ['glutenfrei']
# 65471                                     ['glutenfrei']
# 65472                                     ['glutenfrei']
# 65473                                     ['glutenfrei']
# 65474                                     ['glutenfrei']
# 65475                                     ['glutenfrei']
# 65476                                     ['glutenfrei']
# 65477                                     ['glutenfrei']
# 65478                                     ['glutenfrei']
# 65479                                     ['glutenfrei']
# 65480                                     ['glutenfrei']
# 65481                                     ['glutenfrei']
# 65482                                     ['glutenfrei']
# 65483                                     ['glutenfrei']
# 65484                      ['glutenfrei', 'laktosefrei']
# 65485                      ['glutenfrei', 'laktosefrei']
# 65486                      ['glutenfrei', 'laktosefrei']
# 65487                                     ['glutenfrei']
# 65488                                     ['glutenfrei']
# 65489                                     ['glutenfrei']
# 65490                      ['glutenfrei', 'laktosefrei']
# 65491                                     ['glutenfrei']
# 65492                                     ['glutenfrei']
# 65493                                     ['glutenfrei']
# 65494                                     ['glutenfrei']
# 65495                                                NaN
# 65496                                                NaN
# 65497                                                NaN
# 65498                                                NaN
#
#                   cuisine_characteristics            taste_characteristics  \
# 0       ['gesundes essen', 'italienisch']           ['mild', 'natuerlich']
# 1       ['gesundes essen', 'italienisch']                   ['natuerlich']
# 2       ['gesundes essen', 'italienisch']           ['mild', 'natuerlich']
# 3                         ['italienisch']                   ['natuerlich']
# 4       ['gesundes essen', 'italienisch']                   ['natuerlich']
# 5      ['amerikanisch', 'gesundes essen']           ['mild', 'natuerlich']
# 6      ['amerikanisch', 'gesundes essen']           ['mild', 'natuerlich']
# 7      ['amerikanisch', 'gesundes essen']  ['leicht scharf', 'natuerlich']
# 8      ['amerikanisch', 'gesundes essen']                   ['natuerlich']
# 9                       ['international']                   ['natuerlich']
# 10                             ['salate']           ['mild', 'natuerlich']
# 11                                    NaN                              NaN
# 12                                    NaN                              NaN
# 13                                    NaN                              NaN
# 14                                    NaN                              NaN
# 15                        ['italienisch']                   ['natuerlich']
# 16                        ['italienisch']                         ['mild']
# 17                        ['italienisch']                         ['mild']
# 18                        ['italienisch']                         ['mild']
# 19                        ['italienisch']                         ['mild']
# 20                        ['italienisch']                         ['mild']
# 21                        ['italienisch']                         ['mild']
# 22                        ['italienisch']                       ['scharf']
# 23                        ['italienisch']                       ['scharf']
# 24                        ['italienisch']                   ['natuerlich']
# 25                        ['italienisch']                   ['natuerlich']
# 26                        ['italienisch']                         ['mild']
# 27                        ['italienisch']                ['leicht scharf']
# 28                        ['italienisch']                         ['mild']
# 29                        ['italienisch']                   ['natuerlich']
# ...                                   ...                              ...
# 65469                      ['griechisch']                         ['mild']
# 65470                      ['griechisch']                ['leicht scharf']
# 65471                      ['griechisch']                         ['mild']
# 65472                      ['griechisch']                         ['mild']
# 65473                      ['griechisch']                         ['mild']
# 65474                      ['griechisch']                         ['mild']
# 65475                      ['griechisch']                         ['mild']
# 65476                      ['griechisch']                         ['mild']
# 65477                      ['griechisch']                         ['mild']
# 65478                      ['griechisch']                         ['mild']
# 65479                      ['griechisch']                         ['mild']
# 65480                      ['griechisch']                         ['mild']
# 65481                      ['griechisch']                ['leicht scharf']
# 65482                      ['griechisch']                ['leicht scharf']
# 65483                      ['griechisch']                         ['mild']
# 65484                      ['griechisch']                         ['mild']
# 65485                      ['griechisch']                         ['mild']
# 65486                      ['griechisch']                         ['mild']
# 65487                      ['griechisch']                         ['mild']
# 65488                      ['griechisch']                         ['mild']
# 65489                      ['griechisch']                         ['mild']
# 65490                      ['griechisch']                         ['mild']
# 65491                      ['griechisch']                         ['mild']
# 65492                      ['griechisch']                         ['mild']
# 65493                      ['griechisch']                         ['mild']
# 65494                      ['griechisch']                         ['mild']
# 65495                                 NaN                              NaN
# 65496                                 NaN                              NaN
# 65497                                 NaN                              NaN
# 65498                                 NaN                              NaN
#
#       preparation_style_characteristics dish_type_characteristics  \
# 0                          ['gebacken']                 ['pizza']
# 1                          ['gebacken']                 ['pizza']
# 2                          ['gebacken']                 ['pizza']
# 3                          ['gebacken']                 ['pizza']
# 4                          ['gebacken']                 ['pizza']
# 5                          ['gebraten']                ['burger']
# 6                          ['gebraten']                ['burger']
# 7                          ['gebraten']                ['burger']
# 8             ['frittiert', 'gebacken']                ['pommes']
# 9                    ['fusion   mixed']                 ['extra']
# 10                              ['roh']                 ['salat']
# 11                                  NaN                       NaN
# 12                                  NaN                       NaN
# 13                                  NaN                       NaN
# 14                                  NaN                       NaN
# 15                  ['gegrillt', 'roh']    ['fleisch', 'gemuese']
# 16                              ['roh']                 ['salat']
# 17                              ['roh']                 ['salat']
# 18                  ['gebraten', 'roh']                 ['salat']
# 19                              ['roh']                 ['salat']
# 20                  ['gebraten', 'roh']                 ['salat']
# 21                          ['gekocht']                 ['pasta']
# 22                          ['gekocht']                 ['pasta']
# 23                          ['gekocht']                 ['pasta']
# 24                          ['gekocht']                 ['pasta']
# 25                          ['gekocht']                 ['pasta']
# 26                          ['gekocht']                 ['pasta']
# 27                          ['gekocht']                 ['pasta']
# 28                         ['gebacken']                 ['pizza']
# 29                         ['gebacken']                 ['pizza']
# ...                                 ...                       ...
# 65469                      ['gegrillt']               ['fleisch']
# 65470                      ['gegrillt']               ['fleisch']
# 65471                      ['gegrillt']               ['fleisch']
# 65472                      ['gegrillt']               ['fleisch']
# 65473                      ['gegrillt']               ['fleisch']
# 65474                      ['gegrillt']               ['fleisch']
# 65475                      ['gegrillt']               ['fleisch']
# 65476                      ['gegrillt']               ['fleisch']
# 65477                      ['gegrillt']               ['fleisch']
# 65478                      ['gegrillt']               ['fleisch']
# 65479                      ['gegrillt']               ['fleisch']
# 65480                      ['gegrillt']               ['fleisch']
# 65481          ['gebraten', 'gegrillt']               ['fleisch']
# 65482          ['gebraten', 'gegrillt']               ['fleisch']
# 65483                      ['gegrillt']               ['fleisch']
# 65484                      ['gegrillt']               ['fleisch']
# 65485                      ['gegrillt']               ['fleisch']
# 65486                      ['gegrillt']               ['fleisch']
# 65487                      ['gegrillt']               ['fleisch']
# 65488                      ['gegrillt']               ['fleisch']
# 65489                      ['gegrillt']               ['fleisch']
# 65490                      ['gegrillt']                 ['fisch']
# 65491         ['gebraten', 'mariniert']                 ['fisch']
# 65492                     ['frittiert']                 ['fisch']
# 65493                      ['gegrillt']                 ['fisch']
# 65494                      ['gegrillt']                 ['fisch']
# 65495                               NaN                       NaN
# 65496                               NaN                       NaN
# 65497                               NaN                       NaN
# 65498                               NaN                       NaN
#
#                                              ingredients
# 0                           ['kaese', 'mehl', 'tomaten']
# 1      ['kaese', 'mehl', 'salami', 'schinken', 'tomat...
# 2      ['kaese', 'mehl', 'pilz', 'rucola', 'tomatensa...
# 3                                           ['jalapeno']
# 4      ['haehnchenbrustfilet', 'kaese', 'mehl', 'toma...
# 5      ['eisbergsalat', 'gurke', 'rindfleisch', 'toma...
# 6      ['eisbergsalat', 'gurke', 'kaese', 'rindfleisc...
# 7                   ['jalapeno', 'rindfleisch', 'salat']
# 8                                          ['kartoffel']
# 9                                         ['krautsalat']
# 10     ['haehnchenbrustfilet', 'salat', 'salat dressi...
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                 ['burrata mozarella']
# 16                       ['gurke', 'karotte', 'tomaten']
# 17                      ['burrata mozarella', 'tomaten']
# 18                                  ['salat', 'tomaten']
# 19                   ['ei', 'olive', 'salat', 'zwiebel']
# 20                  ['mandel', 'tomaten', 'ziegenkaese']
# 21                                         ['basilikum']
# 22                                         ['olivenoel']
# 23                                         ['olivenoel']
# 24                                    ['ei', 'parmesan']
# 25                                       ['rindfleisch']
# 26                                ['paprika', 'tomaten']
# 27                                       ['rindfleisch']
# 28                           ['basilikum', 'mozzarella']
# 29                              ['mozzarella', 'salami']
# ...                                                  ...
# 65469                                 ['aleppo pfeffer']
# 65470                                 ['aleppo pfeffer']
# 65471                                 ['aleppo pfeffer']
# 65472                                 ['aleppo pfeffer']
# 65473                                 ['aleppo pfeffer']
# 65474                                 ['aleppo pfeffer']
# 65475                                 ['aleppo pfeffer']
# 65476                                 ['aleppo pfeffer']
# 65477                                 ['aleppo pfeffer']
# 65478                                 ['aleppo pfeffer']
# 65479                                 ['aleppo pfeffer']
# 65480                                 ['aleppo pfeffer']
# 65481                                 ['aleppo pfeffer']
# 65482                                 ['aleppo pfeffer']
# 65483                                 ['aleppo pfeffer']
# 65484                                 ['aleppo pfeffer']
# 65485                                 ['aleppo pfeffer']
# 65486                                 ['aleppo pfeffer']
# 65487                                 ['aleppo pfeffer']
# 65488                                 ['aleppo pfeffer']
# 65489                                 ['aleppo pfeffer']
# 65490                                 ['aleppo pfeffer']
# 65491                                 ['aleppo pfeffer']
# 65492                                 ['aleppo pfeffer']
# 65493                                 ['aleppo pfeffer']
# 65494                                 ['aleppo pfeffer']
# 65495                                                NaN
# 65496                                                NaN
# 65497                                                NaN
# 65498                                                NaN
#
# [65499 rows x 22 columns]

# %%
print data.isnull().sum()
# Out:
# restaurant_id                            0
# restaurant_name                          0
# testing                                  0
# restaurant_description                 257
# product_id                               0
# variation_id                             0
# menu_category                            5
# product_name                            13
# product_description                   3895
# price                                    0
# postcode                               652
# latitude                               224
# longitude                              223
# chain_id                             61193
# restaurant_active                        0
# city_id                                  0
# dietary_characteristics              53810
# cuisine_characteristics              41771
# taste_characteristics                41771
# preparation_style_characteristics    41771
# dish_type_characteristics            41771
# ingredients                          41784
# dtype: int64

# %%
# from this we can see that there is missing data mostly 
# for chain_id so I would not use this column
# as a feature, lots of data is mising for dietary characteristics as for 
# cuisine, taste, preparation, dish type and ingredients
# however I belive that some of this information might 
# be valuable for predictions, for example the ingredients
# I would include data from this columns probably in the latter steps, 
# since it needs to be correctly parsed and mapped first

# %%
print 'Unique restaurant_id: {}'.format(len(data['restaurant_id'].unique()))
print 'Unique restaurant_name: {}'.format(len(data['restaurant_name'].unique()))
print 'Unique restaurant_description: {}'.format(len(data['restaurant_description'].unique()))
print 'Unique product_id: {}'.format(len(data['product_id'].unique()))
print 'Unique variation_id: {}'.format(len(data['variation_id'].unique()))
print 'Unique menu_category: {}'.format(len(data['menu_category'].unique()))
print 'Unique product_name: {}'.format(len(data['product_name'].unique()))
print 'Unique city_id: {}'.format(len(data['city_id'].unique()))
print 'Unique postcode: {}'.format(len(data['postcode'].unique()))
print 'Unique (longitude, latitude) pairs: {}'.format(\
                len(set(zip(data['longitude'],data['latitude']))))
print 'Inactive restaurants: {}'.format(\
                    data['restaurant_active'].where(\
                    data['restaurant_active']==0).isnull().sum())
print 'Unique prices: {}'.format(len(data['price'].unique()))
print 'Minial price: {}'.format(min(data['price']))
print 'Maximal price: {}'.format(min(data['price']))
print 'Mean of price: {}'.format(np.mean(data['price']))
print 'Median of price: {}'.format(np.median(data['price']))
print 'Std of price: {}'.format(np.std(data['price']))
# Out:
# Unique restaurant_id: 1520
# Unique restaurant_name: 1515
# Unique restaurant_description: 1307
# Unique product_id: 65495
# Unique variation_id: 65499
# Unique menu_category: 3334
# Unique product_name: 44844
# Unique city_id: 14
# Unique postcode: 278
# Unique (longitude, latitude) pairs: 1702
# Inactive restaurants: 26657
# Unique prices: 730
# Minial price: 0.0
# Maximal price: 0.0
# Mean of price: 8.78614452129
# Median of price: 7.0
# Std of price: 10.4801397226

# %%
# From this we can see that product_id and variation_id 
# basicaly bring no information, i.e are probably sort of database ids
# restaurant_id and restarurant_name are encoding the same information 
# so one can use either, using the id for start is more clear approach,
# it is catecorized and don't need to be manipulated a lot
# Restaurants_descripton I suppose would not bring too much significat information too
# So for start as features I am taking menu_category, product_name
# product_description is definitely worth using but migth need more preprocessing
# It is imortant to note that the price has very big discrepancy between
# the mean and median value, and thus very high standard deviation
# Since city_id, postcode and location are categorical values I 
# will shortly have a look in their correlation with price to decide which to use

# %%
# before I analyse and plot I will endode the data in categorical values
def encode_column(col):
    loc_keys = col.unique()
    loc_vals = range(len(loc_keys))
    loc_dict = {k:v for k,v in zip(loc_keys,loc_vals)}
    col=col.apply(lambda x: loc_dict[x])
    return col
data['location'] = zip(data['longitude'],data['latitude'])
data['location'] = encode_column(data['location'])
# I noticed there are some names in the postcode
# so remove all chars except numbers
data['postcode'].replace({r'[^0-9]':''}, regex=True, inplace=True)
data['postcode'] = encode_column(data['postcode'])
data['city_id'] = encode_column(data['city_id'])
data
# Out:
#        restaurant_id      restaurant_name  testing  \
# 0                453  fit kitchen eat fit        0
# 1                453  fit kitchen eat fit        0
# 2                453  fit kitchen eat fit        0
# 3                453  fit kitchen eat fit        0
# 4                453  fit kitchen eat fit        0
# 5                453  fit kitchen eat fit        0
# 6                453  fit kitchen eat fit        0
# 7                453  fit kitchen eat fit        0
# 8                453  fit kitchen eat fit        0
# 9                453  fit kitchen eat fit        0
# 10               453  fit kitchen eat fit        0
# 11               453  fit kitchen eat fit        0
# 12               453  fit kitchen eat fit        0
# 13               453  fit kitchen eat fit        0
# 14               453  fit kitchen eat fit        0
# 15               358           a tavola !        0
# 16               358           a tavola !        0
# 17               358           a tavola !        0
# 18               358           a tavola !        0
# 19               358           a tavola !        0
# 20               358           a tavola !        0
# 21               358           a tavola !        0
# 22               358           a tavola !        0
# 23               358           a tavola !        0
# 24               358           a tavola !        0
# 25               358           a tavola !        0
# 26               358           a tavola !        0
# 27               358           a tavola !        0
# 28               358           a tavola !        0
# 29               358           a tavola !        0
# ...              ...                  ...      ...
# 65469           8649               kavala        0
# 65470           8649               kavala        0
# 65471           8649               kavala        0
# 65472           8649               kavala        0
# 65473           8649               kavala        0
# 65474           8649               kavala        0
# 65475           8649               kavala        0
# 65476           8649               kavala        0
# 65477           8649               kavala        0
# 65478           8649               kavala        0
# 65479           8649               kavala        0
# 65480           8649               kavala        0
# 65481           8649               kavala        0
# 65482           8649               kavala        0
# 65483           8649               kavala        0
# 65484           8649               kavala        0
# 65485           8649               kavala        0
# 65486           8649               kavala        0
# 65487           8649               kavala        0
# 65488           8649               kavala        0
# 65489           8649               kavala        0
# 65490           8649               kavala        0
# 65491           8649               kavala        0
# 65492           8649               kavala        0
# 65493           8649               kavala        0
# 65494           8649               kavala        0
# 65495           8649               kavala        0
# 65496           8649               kavala        0
# 65497           8649               kavala        0
# 65498           8649               kavala        0
#
#                   restaurant_description  product_id  variation_id  \
# 0                     gesundes fast food       35039         35037
# 1                     gesundes fast food       35040         35038
# 2                     gesundes fast food       35043         35041
# 3                     gesundes fast food       35045         35043
# 4                     gesundes fast food       35046         35044
# 5                     gesundes fast food       35051         35049
# 6                     gesundes fast food       35052         35050
# 7                     gesundes fast food       35053         35051
# 8                     gesundes fast food       35059         35057
# 9                     gesundes fast food       35060         35058
# 10                    gesundes fast food       35063         35061
# 11                    gesundes fast food       35069         35067
# 12                    gesundes fast food       35070         35068
# 13                    gesundes fast food       35082         35080
# 14                    gesundes fast food       35083         35081
# 15                 feinstes bella italia       35102         35100
# 16                 feinstes bella italia       35103         35101
# 17                 feinstes bella italia       35105         35103
# 18                 feinstes bella italia       35106         35104
# 19                 feinstes bella italia       35107         35105
# 20                 feinstes bella italia       35108         35106
# 21                 feinstes bella italia       35109         35107
# 22                 feinstes bella italia       35110         35108
# 23                 feinstes bella italia       35111         35109
# 24                 feinstes bella italia       35112         35110
# 25                 feinstes bella italia       35113         35111
# 26                 feinstes bella italia       35114         35112
# 27                 feinstes bella italia       35116         35114
# 28                 feinstes bella italia       35122         35120
# 29                 feinstes bella italia       35123         35121
# ...                                  ...         ...           ...
# 65469  goettliche gerichte griechenlands      219983        220669
# 65470  goettliche gerichte griechenlands      219984        220670
# 65471  goettliche gerichte griechenlands      219985        220671
# 65472  goettliche gerichte griechenlands      219986        220672
# 65473  goettliche gerichte griechenlands      219987        220673
# 65474  goettliche gerichte griechenlands      219988        220674
# 65475  goettliche gerichte griechenlands      219989        220675
# 65476  goettliche gerichte griechenlands      219990        220676
# 65477  goettliche gerichte griechenlands      219991        220677
# 65478  goettliche gerichte griechenlands      219992        220678
# 65479  goettliche gerichte griechenlands      219993        220679
# 65480  goettliche gerichte griechenlands      219994        220680
# 65481  goettliche gerichte griechenlands      219996        220682
# 65482  goettliche gerichte griechenlands      219997        220683
# 65483  goettliche gerichte griechenlands      220001        220687
# 65484  goettliche gerichte griechenlands      220002        220688
# 65485  goettliche gerichte griechenlands      220003        220689
# 65486  goettliche gerichte griechenlands      220004        220690
# 65487  goettliche gerichte griechenlands      220005        220691
# 65488  goettliche gerichte griechenlands      220006        220692
# 65489  goettliche gerichte griechenlands      220007        220693
# 65490  goettliche gerichte griechenlands      220015        220701
# 65491  goettliche gerichte griechenlands      220016        220702
# 65492  goettliche gerichte griechenlands      220018        220704
# 65493  goettliche gerichte griechenlands      220019        220705
# 65494  goettliche gerichte griechenlands      220020        220706
# 65495  goettliche gerichte griechenlands      220022        220708
# 65496  goettliche gerichte griechenlands      220023        220709
# 65497  goettliche gerichte griechenlands      220024        220710
# 65498  goettliche gerichte griechenlands      220025        220711
#
#                   menu_category                                 product_name  \
# 0                     fit pizza                             pizza margherita
# 1                     fit pizza                  pizza salami, putenschinken
# 2                     fit pizza                        pizza veggie + rucola
# 3                     fit pizza                        pizza sucuk jalapenos
# 4                     fit pizza                         pizza haehnchenbrust
# 5                    fit burger                              classic burger
# 6                    fit burger                                cheese burger
# 7                    fit burger                          chili cheese burger
# 8                  fit beilagen                                   fit pommes
# 9                  fit beilagen                                 fit coleslaw
# 10                    fit salat                         haehnchenbrust salat
# 11                    getraenke                  afri kola zuckerfrei, 0,33l
# 12                    getraenke                             afri kola, 0,33l
# 13                    getraenke  elisabethen quelle ohne kohlensaeure, 0,25l
# 14                    getraenke   elisabethen quelle mit kohlensaeure, 0,25l
# 15                    antipasti                           antipasti italiani
# 16                     insalate                               insalata mista
# 17                     insalate                             insalata caprese
# 18                     insalate                            insalata di pollo
# 19                     insalate                          insalata della casa
# 20                     insalate                            insalata di capra
# 21                        pasta                        spaghetti al pomodoro
# 22                        pasta                spaghetti aglio e peperoncino
# 23                        pasta                              penne arrabiata
# 24                        pasta                     spaghetti alla carbonara
# 25                        pasta                     spaghetti alla bolognese
# 26                        pasta                                penne verdure
# 27                        pasta                              penne salsiccia
# 28                        pizza                             pizza margherita
# 29                        pizza                                 pizza salami
# ...                         ...                                          ...
# 65469  spezialitaeten vom grill                         schweinefilet kavala
# 65470  spezialitaeten vom grill                schweinefilet in metaxa sauce
# 65471  spezialitaeten vom grill                               peramos teller
# 65472  spezialitaeten vom grill                              phillipi teller
# 65473  spezialitaeten vom grill                                  joti teller
# 65474  spezialitaeten vom grill                              keramoti teller
# 65475  spezialitaeten vom grill                             iraklitsa teller
# 65476  spezialitaeten vom grill                           rumpsteak vom rind
# 65477  spezialitaeten vom grill                                schweinefilet
# 65478  spezialitaeten vom grill                               spiesse teller
# 65479  spezialitaeten vom grill                                 filet spiess
# 65480                   platten                    platte fuer zwei personen
# 65481           pfannengerichte                                 gyros pfanne
# 65482           pfannengerichte                                 puten pfanne
# 65483              lammgerichte                          lammfilets gegrillt
# 65484              lammgerichte                                     arnissia
# 65485              lammgerichte                               lammkotelettes
# 65486              lammgerichte                                  lamm teller
# 65487              lammgerichte                 lammsteak mit kraeuterbutter
# 65488              lammgerichte                   lammsteak mit metaxa sauce
# 65489              lammgerichte               lamm platte fuer zwei personen
# 65490             fischgerichte                            garnelen gegrillt
# 65491             fischgerichte                      rotbarschfilet gebraten
# 65492             fischgerichte                     baby calamares frittiert
# 65493             fischgerichte                              dorade gegrillt
# 65494             fischgerichte                      baby calamares gegrillt
# 65495     erfrischungsgetraenke                              coca cola, 1,0l
# 65496     erfrischungsgetraenke                                  fanta, 1,0l
# 65497     erfrischungsgetraenke                                 sprite, 1,0l
# 65498     erfrischungsgetraenke                       coca cola light, 0,33l
#
#                                      product_description  price   ...     \
# 0                       tomatensauce und fettarmer kaese    6.0   ...
# 1      fettarme salami, putenschinken und fettarmer k...    8.4   ...
# 2            pilze, zwiebeln, rucola und fettarmer kaese    8.4   ...
# 3      fettarme knoblauchwurst, jalapenos und fettarm...    8.4   ...
# 4      magere haehnchenbruststreifen, pilze, zwiebeln...    8.9   ...
# 5      mageres rindfleisch, eisbergsalat, tomaten, zw...    5.9   ...
# 6      mageres rindfleisch, low fat kaese, eisbergsal...    6.4   ...
# 7      mageres rindfleisch, salat, jalapenos und fit ...    7.4   ...
# 8                        mit heissluft frittierte pommes    2.9   ...
# 9                                   fettarmer krautsalat    2.9   ...
# 10     gemischter salat, haehnchenbruststreifen, dazu...    7.9   ...
# 11     erfrischungsgetraenk, inkl. 0,08 pfand, 8,55 l...    2.9   ...
# 12     erfrischungsgetraenk, inkl. 0,08 pfand, 8,55 l...    2.9   ...
# 13                  wasser, inkl. 0,15 pfand, 8,20 liter    2.2   ...
# 14                  wasser, inkl. 0,15 pfand, 8,20 liter    2.2   ...
# 15     bresaola schinken, salami, parmesan, champigno...   10.5   ...
# 16     verschiedene salate, tomaten, karotten, gurken...    6.0   ...
# 17                        tomaten, burrata und basilikum    8.5   ...
# 18     verschiedene salate, tomaten und gebratene hae...   10.5   ...
# 19       blattsalate, thunfisch, oliven, zwiebeln und ei   10.0   ...
# 20     rucolasalat mir warmen ziegenkaese, kirschtoma...    9.5   ...
# 21                             tomatensugo und basilikum    6.5   ...
# 22            knoblauch, chili, olivenoel und petersilie    7.5   ...
# 23         mit tomatensauce, basilikum, knoblauch scharf    8.0   ...
# 24                               ei und speck ohne sahne    9.5   ...
# 25                          mit rinderhackfleisch ragout    9.5   ...
# 26                     tomatensauce und frisches gemuese    9.0   ...
# 27     pikante salsiccia, tomaten und weisswein tomat...   11.0   ...
# 28                              mozzarella und basilikum    6.0   ...
# 29                                 mozzarella und salami    7.0   ...
# ...                                                  ...    ...   ...
# 65469  vier schweinefilets mit kraeuterbutter, dazu p...   13.9   ...
# 65470  in metaxa sauce mit gouda ueberbacken, dazu po...   14.5   ...
# 65471  souvlaki, lammkotelett, ÄevapÄiÄi, schweine...   14.9   ...
# 65472  gyros, zwei ÄevapÄiÄi, schweinefilet und tz...   13.5   ...
# 65473  gyros, schweinesteak, schweinefilet, souvlaki,...   14.9   ...
# 65474  gyros, souvlaki, lammkotelett und tzatziki, da...   14.5   ...
# 65475  souvlaki, zwei ÄevapÄiÄi, schweinefilet, la...   14.9   ...
# 65476  mit kraeuterbutter, dazu pommes frites und sal...   16.9   ...
# 65477                  mit pommes frites, reis und salat   14.5   ...
# 65478  ein schweinefleischspiess und ein lammfleischs...   12.9   ...
# 65479  ein grosser schweinefiletspiess mit zwiebeln u...   14.2   ...
# 65480  als vorspeise: tzatziki, tarama, krautsalat, t...   31.5   ...
# 65481  in metaxa sauce, dazu pommes frites und salat,...   11.9   ...
# 65482  in metaxa sauce, dazu pommes frites und salat,...   11.9   ...
# 65483  mit kraeuterbutter, dazu pommes frites und sal...   15.9   ...
# 65484  zwei lammspiesse, dazu pommes frites und salat...   13.9   ...
# 65485  4 stueck, dazu pommes frites und salat, auf wu...   14.9   ...
# 65486  zwei lammkoteletts, ein lammspiess und ein kle...   17.5   ...
# 65487  mit kraeuterbutter, dazu pommes frites und sal...   14.9   ...
# 65488  mit metaxa sauce, dazu pommes frites und salat...   15.9   ...
# 65489  als vorspeise: tzatziki, tarama, krautsalat, t...   35.9   ...
# 65490  dazu pommes frites und salat, auf wunsch auch ...   16.9   ...
# 65491  dazu pommes frites und salat, auf wunsch auch ...   11.9   ...
# 65492  dazu pommes frites und salat, auf wunsch auch ...   13.5   ...
# 65493  dazu pommes frites und salat, auf wunsch auch ...   17.5   ...
# 65494  dazu pommes frites und salat, auf wunsch auch ...   13.5   ...
# 65495  erfrischungsgetraenk, inkl. 0,15 pfand, 2,35 l...    2.5   ...
# 65496  erfrischungsgetraenk, inkl. 0,15 pfand, 2,35 l...    2.5   ...
# 65497  erfrischungsgetraenk, inkl. 0,15 pfand, 2,35 l...    2.5   ...
# 65498  erfrischungsgetraenk, dose, inkl. 0,25 pfand, ...    2.2   ...
#
#        chain_id  restaurant_active  city_id  \
# 0           NaN                  1        0
# 1           NaN                  1        0
# 2           NaN                  1        0
# 3           NaN                  1        0
# 4           NaN                  1        0
# 5           NaN                  1        0
# 6           NaN                  1        0
# 7           NaN                  1        0
# 8           NaN                  1        0
# 9           NaN                  1        0
# 10          NaN                  1        0
# 11          NaN                  1        0
# 12          NaN                  1        0
# 13          NaN                  1        0
# 14          NaN                  1        0
# 15          NaN                  1        0
# 16          NaN                  1        0
# 17          NaN                  1        0
# 18          NaN                  1        0
# 19          NaN                  1        0
# 20          NaN                  1        0
# 21          NaN                  1        0
# 22          NaN                  1        0
# 23          NaN                  1        0
# 24          NaN                  1        0
# 25          NaN                  1        0
# 26          NaN                  1        0
# 27          NaN                  1        0
# 28          NaN                  1        0
# 29          NaN                  1        0
# ...         ...                ...      ...
# 65469       NaN                  1        3
# 65470       NaN                  1        3
# 65471       NaN                  1        3
# 65472       NaN                  1        3
# 65473       NaN                  1        3
# 65474       NaN                  1        3
# 65475       NaN                  1        3
# 65476       NaN                  1        3
# 65477       NaN                  1        3
# 65478       NaN                  1        3
# 65479       NaN                  1        3
# 65480       NaN                  1        3
# 65481       NaN                  1        3
# 65482       NaN                  1        3
# 65483       NaN                  1        3
# 65484       NaN                  1        3
# 65485       NaN                  1        3
# 65486       NaN                  1        3
# 65487       NaN                  1        3
# 65488       NaN                  1        3
# 65489       NaN                  1        3
# 65490       NaN                  1        3
# 65491       NaN                  1        3
# 65492       NaN                  1        3
# 65493       NaN                  1        3
# 65494       NaN                  1        3
# 65495       NaN                  1        3
# 65496       NaN                  1        3
# 65497       NaN                  1        3
# 65498       NaN                  1        3
#
#                                  dietary_characteristics  \
# 0                                  ['lakto vegetarisch']
# 1                                  ['lakto vegetarisch']
# 2      ['lakto vegetarisch', 'ohne rindfleisch', 'ohn...
# 3                                                    NaN
# 4                                              ['halal']
# 5                               ['ohne schweinefleisch']
# 6                               ['ohne schweinefleisch']
# 7                               ['ohne schweinefleisch']
# 8                                              ['vegan']
# 9                                                    NaN
# 10          ['ohne rindfleisch', 'ohne schweinefleisch']
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                        ['biologisch']
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21          ['ohne rindfleisch', 'ohne schweinefleisch']
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                              ['ohne schweinefleisch']
# 26                                                   NaN
# 27                              ['ohne schweinefleisch']
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 65469                      ['glutenfrei', 'laktosefrei']
# 65470                                     ['glutenfrei']
# 65471                                     ['glutenfrei']
# 65472                                     ['glutenfrei']
# 65473                                     ['glutenfrei']
# 65474                                     ['glutenfrei']
# 65475                                     ['glutenfrei']
# 65476                                     ['glutenfrei']
# 65477                                     ['glutenfrei']
# 65478                                     ['glutenfrei']
# 65479                                     ['glutenfrei']
# 65480                                     ['glutenfrei']
# 65481                                     ['glutenfrei']
# 65482                                     ['glutenfrei']
# 65483                                     ['glutenfrei']
# 65484                      ['glutenfrei', 'laktosefrei']
# 65485                      ['glutenfrei', 'laktosefrei']
# 65486                      ['glutenfrei', 'laktosefrei']
# 65487                                     ['glutenfrei']
# 65488                                     ['glutenfrei']
# 65489                                     ['glutenfrei']
# 65490                      ['glutenfrei', 'laktosefrei']
# 65491                                     ['glutenfrei']
# 65492                                     ['glutenfrei']
# 65493                                     ['glutenfrei']
# 65494                                     ['glutenfrei']
# 65495                                                NaN
# 65496                                                NaN
# 65497                                                NaN
# 65498                                                NaN
#
#                   cuisine_characteristics            taste_characteristics  \
# 0       ['gesundes essen', 'italienisch']           ['mild', 'natuerlich']
# 1       ['gesundes essen', 'italienisch']                   ['natuerlich']
# 2       ['gesundes essen', 'italienisch']           ['mild', 'natuerlich']
# 3                         ['italienisch']                   ['natuerlich']
# 4       ['gesundes essen', 'italienisch']                   ['natuerlich']
# 5      ['amerikanisch', 'gesundes essen']           ['mild', 'natuerlich']
# 6      ['amerikanisch', 'gesundes essen']           ['mild', 'natuerlich']
# 7      ['amerikanisch', 'gesundes essen']  ['leicht scharf', 'natuerlich']
# 8      ['amerikanisch', 'gesundes essen']                   ['natuerlich']
# 9                       ['international']                   ['natuerlich']
# 10                             ['salate']           ['mild', 'natuerlich']
# 11                                    NaN                              NaN
# 12                                    NaN                              NaN
# 13                                    NaN                              NaN
# 14                                    NaN                              NaN
# 15                        ['italienisch']                   ['natuerlich']
# 16                        ['italienisch']                         ['mild']
# 17                        ['italienisch']                         ['mild']
# 18                        ['italienisch']                         ['mild']
# 19                        ['italienisch']                         ['mild']
# 20                        ['italienisch']                         ['mild']
# 21                        ['italienisch']                         ['mild']
# 22                        ['italienisch']                       ['scharf']
# 23                        ['italienisch']                       ['scharf']
# 24                        ['italienisch']                   ['natuerlich']
# 25                        ['italienisch']                   ['natuerlich']
# 26                        ['italienisch']                         ['mild']
# 27                        ['italienisch']                ['leicht scharf']
# 28                        ['italienisch']                         ['mild']
# 29                        ['italienisch']                   ['natuerlich']
# ...                                   ...                              ...
# 65469                      ['griechisch']                         ['mild']
# 65470                      ['griechisch']                ['leicht scharf']
# 65471                      ['griechisch']                         ['mild']
# 65472                      ['griechisch']                         ['mild']
# 65473                      ['griechisch']                         ['mild']
# 65474                      ['griechisch']                         ['mild']
# 65475                      ['griechisch']                         ['mild']
# 65476                      ['griechisch']                         ['mild']
# 65477                      ['griechisch']                         ['mild']
# 65478                      ['griechisch']                         ['mild']
# 65479                      ['griechisch']                         ['mild']
# 65480                      ['griechisch']                         ['mild']
# 65481                      ['griechisch']                ['leicht scharf']
# 65482                      ['griechisch']                ['leicht scharf']
# 65483                      ['griechisch']                         ['mild']
# 65484                      ['griechisch']                         ['mild']
# 65485                      ['griechisch']                         ['mild']
# 65486                      ['griechisch']                         ['mild']
# 65487                      ['griechisch']                         ['mild']
# 65488                      ['griechisch']                         ['mild']
# 65489                      ['griechisch']                         ['mild']
# 65490                      ['griechisch']                         ['mild']
# 65491                      ['griechisch']                         ['mild']
# 65492                      ['griechisch']                         ['mild']
# 65493                      ['griechisch']                         ['mild']
# 65494                      ['griechisch']                         ['mild']
# 65495                                 NaN                              NaN
# 65496                                 NaN                              NaN
# 65497                                 NaN                              NaN
# 65498                                 NaN                              NaN
#
#       preparation_style_characteristics dish_type_characteristics  \
# 0                          ['gebacken']                 ['pizza']
# 1                          ['gebacken']                 ['pizza']
# 2                          ['gebacken']                 ['pizza']
# 3                          ['gebacken']                 ['pizza']
# 4                          ['gebacken']                 ['pizza']
# 5                          ['gebraten']                ['burger']
# 6                          ['gebraten']                ['burger']
# 7                          ['gebraten']                ['burger']
# 8             ['frittiert', 'gebacken']                ['pommes']
# 9                    ['fusion   mixed']                 ['extra']
# 10                              ['roh']                 ['salat']
# 11                                  NaN                       NaN
# 12                                  NaN                       NaN
# 13                                  NaN                       NaN
# 14                                  NaN                       NaN
# 15                  ['gegrillt', 'roh']    ['fleisch', 'gemuese']
# 16                              ['roh']                 ['salat']
# 17                              ['roh']                 ['salat']
# 18                  ['gebraten', 'roh']                 ['salat']
# 19                              ['roh']                 ['salat']
# 20                  ['gebraten', 'roh']                 ['salat']
# 21                          ['gekocht']                 ['pasta']
# 22                          ['gekocht']                 ['pasta']
# 23                          ['gekocht']                 ['pasta']
# 24                          ['gekocht']                 ['pasta']
# 25                          ['gekocht']                 ['pasta']
# 26                          ['gekocht']                 ['pasta']
# 27                          ['gekocht']                 ['pasta']
# 28                         ['gebacken']                 ['pizza']
# 29                         ['gebacken']                 ['pizza']
# ...                                 ...                       ...
# 65469                      ['gegrillt']               ['fleisch']
# 65470                      ['gegrillt']               ['fleisch']
# 65471                      ['gegrillt']               ['fleisch']
# 65472                      ['gegrillt']               ['fleisch']
# 65473                      ['gegrillt']               ['fleisch']
# 65474                      ['gegrillt']               ['fleisch']
# 65475                      ['gegrillt']               ['fleisch']
# 65476                      ['gegrillt']               ['fleisch']
# 65477                      ['gegrillt']               ['fleisch']
# 65478                      ['gegrillt']               ['fleisch']
# 65479                      ['gegrillt']               ['fleisch']
# 65480                      ['gegrillt']               ['fleisch']
# 65481          ['gebraten', 'gegrillt']               ['fleisch']
# 65482          ['gebraten', 'gegrillt']               ['fleisch']
# 65483                      ['gegrillt']               ['fleisch']
# 65484                      ['gegrillt']               ['fleisch']
# 65485                      ['gegrillt']               ['fleisch']
# 65486                      ['gegrillt']               ['fleisch']
# 65487                      ['gegrillt']               ['fleisch']
# 65488                      ['gegrillt']               ['fleisch']
# 65489                      ['gegrillt']               ['fleisch']
# 65490                      ['gegrillt']                 ['fisch']
# 65491         ['gebraten', 'mariniert']                 ['fisch']
# 65492                     ['frittiert']                 ['fisch']
# 65493                      ['gegrillt']                 ['fisch']
# 65494                      ['gegrillt']                 ['fisch']
# 65495                               NaN                       NaN
# 65496                               NaN                       NaN
# 65497                               NaN                       NaN
# 65498                               NaN                       NaN
#
#                                              ingredients location
# 0                           ['kaese', 'mehl', 'tomaten']        0
# 1      ['kaese', 'mehl', 'salami', 'schinken', 'tomat...        0
# 2      ['kaese', 'mehl', 'pilz', 'rucola', 'tomatensa...        0
# 3                                           ['jalapeno']        0
# 4      ['haehnchenbrustfilet', 'kaese', 'mehl', 'toma...        0
# 5      ['eisbergsalat', 'gurke', 'rindfleisch', 'toma...        0
# 6      ['eisbergsalat', 'gurke', 'kaese', 'rindfleisc...        0
# 7                   ['jalapeno', 'rindfleisch', 'salat']        0
# 8                                          ['kartoffel']        0
# 9                                         ['krautsalat']        0
# 10     ['haehnchenbrustfilet', 'salat', 'salat dressi...        0
# 11                                                   NaN        0
# 12                                                   NaN        0
# 13                                                   NaN        0
# 14                                                   NaN        0
# 15                                 ['burrata mozarella']        1
# 16                       ['gurke', 'karotte', 'tomaten']        1
# 17                      ['burrata mozarella', 'tomaten']        1
# 18                                  ['salat', 'tomaten']        1
# 19                   ['ei', 'olive', 'salat', 'zwiebel']        1
# 20                  ['mandel', 'tomaten', 'ziegenkaese']        1
# 21                                         ['basilikum']        1
# 22                                         ['olivenoel']        1
# 23                                         ['olivenoel']        1
# 24                                    ['ei', 'parmesan']        1
# 25                                       ['rindfleisch']        1
# 26                                ['paprika', 'tomaten']        1
# 27                                       ['rindfleisch']        1
# 28                           ['basilikum', 'mozzarella']        1
# 29                              ['mozzarella', 'salami']        1
# ...                                                  ...      ...
# 65469                                 ['aleppo pfeffer']     1701
# 65470                                 ['aleppo pfeffer']     1701
# 65471                                 ['aleppo pfeffer']     1701
# 65472                                 ['aleppo pfeffer']     1701
# 65473                                 ['aleppo pfeffer']     1701
# 65474                                 ['aleppo pfeffer']     1701
# 65475                                 ['aleppo pfeffer']     1701
# 65476                                 ['aleppo pfeffer']     1701
# 65477                                 ['aleppo pfeffer']     1701
# 65478                                 ['aleppo pfeffer']     1701
# 65479                                 ['aleppo pfeffer']     1701
# 65480                                 ['aleppo pfeffer']     1701
# 65481                                 ['aleppo pfeffer']     1701
# 65482                                 ['aleppo pfeffer']     1701
# 65483                                 ['aleppo pfeffer']     1701
# 65484                                 ['aleppo pfeffer']     1701
# 65485                                 ['aleppo pfeffer']     1701
# 65486                                 ['aleppo pfeffer']     1701
# 65487                                 ['aleppo pfeffer']     1701
# 65488                                 ['aleppo pfeffer']     1701
# 65489                                 ['aleppo pfeffer']     1701
# 65490                                 ['aleppo pfeffer']     1701
# 65491                                 ['aleppo pfeffer']     1701
# 65492                                 ['aleppo pfeffer']     1701
# 65493                                 ['aleppo pfeffer']     1701
# 65494                                 ['aleppo pfeffer']     1701
# 65495                                                NaN     1701
# 65496                                                NaN     1701
# 65497                                                NaN     1701
# 65498                                                NaN     1701
#
# [65499 rows x 23 columns]

# %%
plt.figure()
scatter_matrix(data[['price', 'city_id', 'postcode', 'location']], \
               alpha=0.2, figsize=(6, 6), diagonal='hist')
# plt.show()
# scatter plots are not the best way to evaluate categorical data
# but in this case helps deciding which feature to include
# I would start with city_id since it cleary can detect the cities 
# which have high price ranges
# on the other hand looking into the price, might be worth
# removing these outliers...
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4007b6bed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c1f4acd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c1f155d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c2c25a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f40c2b82790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c2b7ba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c2b11b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c29e0490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f40c20a16d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c2006590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c1ec9890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c20b0e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f40c1e22f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c1db21d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c1d12810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40c1c96a50>]], dtype=object)

# %%
# lets plot some box plots over city_id
# transform the data
grouped=data[['city_id', 'price']].pivot(\
            columns='city_id', index=data.index)
grouped.columns = grouped.columns.droplevel()
print grouped.mean()
print grouped.median()
print grouped.std()
# grouped.boxplot()
# Out:
# city_id
# 0      8.859622
# 1      8.020247
# 2      7.866763
# 3      9.243218
# 4     10.374838
# 5      8.352578
# 6      8.951942
# 7      7.110962
# 8      7.510862
# 9      8.929326
# 10     8.213471
# 11     7.209302
# 12     7.299817
# 13     7.589821
# dtype: float64
# city_id
# 0     7.5
# 1     7.1
# 2     7.5
# 3     7.5
# 4     8.5
# 5     6.0
# 6     5.9
# 7     5.9
# 8     5.9
# 9     8.0
# 10    6.8
# 11    6.0
# 12    5.9
# 13    6.5
# dtype: float64
# city_id
# 0      6.995574
# 1      5.536125
# 2      4.949804
# 3      9.178261
# 4     13.700521
# 5     13.098908
# 6      7.058375
# 7      5.139154
# 8      7.346428
# 9      5.831879
# 10     5.995224
# 11     6.174171
# 12     6.862750
# 13     6.097331
# dtype: float64

# %%
# more or less the distribution of prices across 
# cities is similar, except for 4 and 5 where there
# are some outliers, higher prices, which is evident
# also in the standard deviation value
# grouped_cut=grouped.where(grouped<10.0)
# print grouped_cut.std()
# print grouped_cut.mean()
# print grouped_cut.median()
# grouped_cut.boxplot()

# %%
# select the initial dataset which will be trained, remove nans, they are not to many
# so I will just drop them (~18)
test_df = data[['restaurant_name','city_id',\
        'menu_category','product_name','price']].copy()
test_df.dropna(inplace=True)
test_df.reset_index(inplace=True)
print test_df.isnull().sum()
# Out:
# index              0
# restaurant_name    0
# city_id            0
# menu_category      0
# product_name       0
# price              0
# dtype: int64

# %%
# as first try I will clean little the menu_category and product_name columns
# which helps a but reducing the dimensionality
# helper function
def primary_transform(col):
    col = col.str.encode('ascii', errors='ignore')
    col.replace({r'[^a-zA-Z\s]':''},regex=True,inplace=True)
    col = col.apply(lambda x:GermanStemmer().stem(x))
    return col
test_df['menu_category'] = primary_transform(\
                            test_df['menu_category'])

test_df['product_name'] = primary_transform(\
                            test_df['product_name'])
test_df['restaurant_name'] = primary_transform(\
                            test_df['restaurant_name'])
print len(data['menu_category'].unique()), len(test_df['menu_category'].unique())
print len(data['product_name'].unique()), len(test_df['product_name'].unique())
print len(data['restaurant_name'].unique()), len(test_df['restaurant_name'].unique())
# Out:
# 3334 3202
# 44844 41359
# 1515 1508

# %%
# First I will try with running 1-char grams over the menu_category and product_name
# Here for example I can include also restaurant_name instead of restaurant_id
# Since if I generate dummies over restaurant_id I will get more features 
# than using 1-char gram over restaurant_name, but lets try
# I can try with 2-char grams, 1grams and 2grams (words)
# helper function
def run_vectorizer(col, char_vectorizer):
    vect_col = char_vectorizer.fit_transform(col)
    vect_df=pd.DataFrame(vect_col.toarray())
    prfx = col.name+'_'
    vect_df.columns= [prfx+str(el) for el in vect_df.columns]
    return vect_df

char_vectorizer = CountVectorizer(ngram_range=(1,1),analyzer='char',strip_accents='ascii', token_pattern='\w')
menu_df= run_vectorizer(test_df['menu_category'], char_vectorizer)
prod_df = run_vectorizer(test_df['product_name'], char_vectorizer)
rest_df = run_vectorizer(test_df['restaurant_name'], char_vectorizer)
# print menu_df.head
print prod_df.shape
# Out:
# (65481, 27)

# %%
def get_col_dummies(col):
    d_df = pd.get_dummies(col)
    prfx = col.name+'_'
    d_df.columns= [prfx+str(el) for el in d_df.columns]
    d_df.reset_index(inplace=True)
    d_df.drop(labels=['index'], axis=1,inplace=True)
    return d_df
# restaurant_id = get_col_dummies(test_df['restaurant_id'])
city_id = get_col_dummies(test_df['city_id'])
#cid_csc = city_id.values.tocsr()
# print restaurant_id.shape
# restaurant_id encoded will add 1520 new features 
# so i will now try with the name
# or i can try only with the original caategorical ids?
print city_id.shape
# Out:
# (65481, 14)

# %%
X = pd.concat((menu_df, prod_df, rest_df, city_id), axis=1)
y = test_df['price'].values
print X.shape
print y.shape
# set some split parameters which I can tune
# I will split now to train and test, but I will performe
# cross validation that will internaly use my train set 
# for train-test cross validations
seed = 7
test_size = 0.1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
print X_train.shape
print X_test.shape
# Out:
# (65481, 95)
# (65481,)
# (58932, 95)
# (6549, 95)

# %%
# normalize the training data
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
X_train_noscl = X_train.copy()
X_train = scale.fit_transform(X_train)
print X_train.shape
# normalize testing data
X_test_noscl = X_test.copy()
X_test= scale.fit_transform(X_test)
print X_test.shape
# Out:
# (58932, 95)
# (6549, 95)

# %%
# helper function to calculate mean
# absolute error on the predictions
# is not sensitive on outliers so
# its what I want for now
def calc_mae(y, y_pred):
    s = 0.0
    for real, pred in zip(y,y_pred):
        s+=abs(real-pred)
    return s/y.shape[0]

# %%
# out of curiosity lets try dummy regressor
dummy = DummyRegressor()
dummy.fit(X_train, y_train)
print dummy.score(X_train, y_train) 
print dummy.score(X_test, y_test)
y_pred_dummy = dummy.predict(X_test)
print calc_mae(y_test, y_pred_dummy)
# 0.0
# -4.60667813531e-05
# 4.99922347886
# Out:
# 0.0
# -4.60667813531e-05
# 4.99922347886

# %%
# now I can try several regressors
# lets start with the simplest one
# ridge regression with leave-one-out cv
# and cv=3 both very bad results!
ridge = RidgeCV()
ridge.fit(X_train, y_train)
print ridge.score(X_train, y_train)
print ridge.score(X_test, y_test)
y_pred_ridge = ridge.predict(X_test)
print calc_mae(y_test, y_pred_ridge)
# cv=3
# 0.124112973512
# 0.114624232585
# 4.50893331164
# Out:
# 0.124112973512
# 0.114624232584
# 4.50893331163

# %%
# XGB regressor takes in account the feature names
# let check if they are same and sorted for train and test set
# try:
#     X_train.shape==X_test.shape
# except:
#     print 'The train and test set dont have same features!!!'
# try:
#     X_train.columns==X_test.columns
# except:
#     print 'The columns are not in order, I will resort them'
#     X_test=X_test[X_train.columns]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-12598ac506bf> in <module>()
#      10 #     print 'The columns are not in order, I will resort them'
#      11 #     X_test=X_test[X_train.columns]
# ---> 12 print X_train.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
xgb_cv = GridSearchCV(XGBRegressor(), cv=3, param_grid={
            'max_depth':[3,10], 
            'learning_rate':[0.1, 1], 
            'n_estimators':[50,100,150]
            })
xgb_cv.fit(X_train, y_train)
best=xgb_cv.best_estimator_

# %%
print best
print best.score(X_train, y_train)
print best.score(X_test, y_test)

# %%
y_pred_xgb=best.predict(X_test)
print calc_mae(y_test, y_pred_xgb)

# %%
# rf_cv=GridSearchCV(RandomForestRegressor(), cv=3, param_grid={'n_estimators':[100,150],'max_depth':[4,6,10]})
# xgb_cv.fit(X_train, y_train)
# best=xgb_cv.best_estimator_
# y_pred_xgb=best.predict(X_test)
# print best
# print best.score(X_train, y_train)
# print best.score(X_test, y_test)
# print calc_mae(y_train, y_pred_xgb)

# %%
# Next to try tfidf vectorizer where I can generate ngrams and cut the vocabulary 
# based on the on max and min document frequency

def generate_tfidf_features(texts):
    vectorizer = TfidfVectorizer(ngram_range=(1,2), min_df=5, max_features=1000)
    # n.b. experiment with max_features here. we don't want to have too many features relative to dataset size though.
    # could also be worthwhile to go with maximum here and apply pca after to reduce final dimensionality
    vectorized = vectorizer.fit_transform(texts)
    return vectorized

# text_feats = generate_tfidf_features(texts)

# tfidf_vectorizer = TfidfVectorizer()
# # X_train_v=tfidf_vectorizer.fit_transform(np.hstack(X_train.values))
# # X_test_v=tfidf_vectorizer.fit_transform(np.hstack(X_test.values))
# tfidf_vectorizer = TfidfVectorizer(max_df=18000, min_df=20)
# t_name = tfidf_vectorizer.fit_transform(encode_menu)
# tfidf_vectorizer = TfidfVectorizer(max_df=2000, min_df=20)
# t_menu = tfidf_vectorizer.fit_transform(encode_menu)

# tfidf_vectorizer = TfidfVectorizer()
# t_rname = tfidf_vectorizer.fit_transform(encode_rname)
